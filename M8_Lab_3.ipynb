# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiHarshitha-192/FMML_Assignments/blob/main/M8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-28 15:06:59--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   134MB/s    in 0.5s
#
# 2023-05-28 15:07:00 (134 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 1063   1611.07743v1  When humans learn a new concept, they might ig...  stat
# 27076  1702.02359v1  Crowd counting on static images is a challengi...    cs
# 38933   1402.3344v2  We extend the framework of efficient coding, w...    cs
# 34651  1707.07792v1  Time is an important relevance signal when sea...    cs
# 22045   1404.2007v1  We describe a simple, efficient, permutation b...  stat
# ...             ...                                                ...   ...
# 680    1703.09387v1  Multiple different approaches of generating ad...    cs
# 4670   1604.01350v1  Within the framework of probably approximately...    cs
# 22883  1710.01167v1  Many machine learning problems can be characte...  stat
# 37926   1201.3973v2  In this paper, we discuss an extension of the ...  stat
# 22461  1608.01234v3  We study the problem of demixing a pair of spa...  stat
#
#                                                    title  year  \
# 1063   Tunable Sensitivity to Large Errors in Neural ...  2016
# 27076  Multi-scale Convolutional Neural Networks for ...  2017
# 38933  Intrinsically Motivated Learning of Visual Mot...  2014
# 34651  Integrating Lexical and Temporal Signals in Ne...  2017
# 22045  A Permutation Approach for Selecting the Penal...  2014
# ...                                                  ...   ...
# 680    Adversarial Transformation Networks: Learning ...  2017
# 4670                  Bounded Optimal Exploration in MDP  2016
# 22883     Decontamination of Mutual Contamination Models  2017
# 37926              Split HMC for Gaussian Process Models  2012
# 22461  Fast Algorithms for Demixing Sparse Signals fr...  2016
#
#                                                 keywords
# 1063   [incorporating, sensitivity, generalization, g...
# 27076  [challenging, variations, effective, complicat...
# 38933  [framework, efficient, development, processing...
# 34651  [important, relevance, searching, distribution...
# 22045  [efficient, permutation, procedure, selecting,...
# ...                                                  ...
# 680    [different, approaches, generating, adversaria...
# 4670   [framework, approximately, processes, theoreti...
# 22883  [characterized, contamination, different, comb...
# 37926  [extension, hamiltonian, splitting, hamiltonia...
# 22461  [nonlinear, observations, superposition, mathe...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 1063     [incorporating, sensitivity, generalization, g...
# 27076    [challenging, variations, effective, complicat...
# 38933    [framework, efficient, development, processing...
# 34651    [important, relevance, searching, distribution...
# 22045    [efficient, permutation, procedure, selecting,...
#                                ...
# 11117    [following, publication, association, consider...
# 24339    [microsoft, transformed, anticipated, develope...
# 13787    [parameter, identification, complexities, calc...
# 21535    [addresses, reverberant, recording, environmen...
# 30509    [questions, estimation, challenges, following,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8847 words.
# Out of those 4599 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="80122749-f2f2-4cb0-a3d5-fecebd04c6d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80122749-f2f2-4cb0-a3d5-fecebd04c6d0")) {                    Plotly.newPlot(                        "80122749-f2f2-4cb0-a3d5-fecebd04c6d0",                        [{"x":["sensitivity","generalization","corroborate","parameterized","benchmark","experiments","positively","prediction","incorporating","generally","correlated","therefore","generalized","applications","outperforms","robustness","performances","architecture","variations","effective","convolutional","parameters","optimization","challenging","computation","practical","complicated","principle","constraints","explanation","framework","reinforcement","integrated","extension","development","properties","environment","selective","directions","perception","different","processing","simultaneous","motivated","efficient","isolation","intrinsically","consisting","intrinsic","competitive","distribution","documents","estimation","relevance","intuition","recurrent","alternative","searching","integrate","expressive","timestamps","implementation","integration","integrating","important","leveraged","similarity","bidirectional","baselines","significant","neighboring","coherence","improvements","knowledge","penalized","selection","structural","connections","procedure","developed","permutation","including","validation","parameter","selecting","information","criterion","procedures","simulation","relationship","temperature","estimates","magnitude","conditions","excluding","associated","sentiment","investigation","meteorological","individuals","precipitation","expressed","occurring","expressions","temperatures","historical","impressive","structure","stochastic","formulation","architectures","regularization","identical","adaptation","remarkably","conclusions","implicitly","conjecture","parameterization","advancement","demonstrate","empirically","evaluation","inception","evaluating","researchers","application","systematic","generative","essential","comparing","accordance","recognition","communication","transfers","corresponding","construct","simulates","individually","principles","handwriting","comprehensive","handwritten","objective","classifier","negligible","empirical","prohibitively","environments","sufficiently","computational","proportional","especially","efficiently","incorporated","minimization","classification","modification","solutions","numerical","algorithms","pioneered","inference","phenomenon","iterative","techniques","probabilistic","criticize","analyzing","distributed","tensorflow","inferences","satisfiability","programming","translation","formalized","comparison","extensions","harnessed","preliminary","declarative","propositional","translating","experimental","particular","performance","philosophy","modelling","computing","difference","dimensions","technique","communications","association","generation","annotation","attitudes","intensities","intensity","automatic"],"y":[48,121,6,13,218,548,4,223,58,67,39,136,81,420,268,98,33,253,66,236,384,254,312,283,158,136,28,43,152,18,573,128,54,105,135,209,116,18,41,35,710,280,25,71,403,11,8,52,44,103,215,69,222,48,12,146,98,24,47,28,3,139,41,31,377,9,161,18,69,258,10,18,118,357,7,141,71,45,118,209,12,258,35,119,23,706,48,31,79,62,9,82,44,146,2,111,57,26,2,36,3,39,17,37,1,24,25,353,127,83,99,87,20,70,13,15,23,14,4,5,535,64,245,8,57,76,240,29,105,72,78,6,399,55,7,119,83,2,12,41,13,58,34,159,149,12,162,8,85,19,298,13,129,170,22,64,523,25,157,65,608,4,206,22,71,362,164,0,58,84,5,17,13,128,102,15,118,41,3,45,8,21,10,361,270,868,8,55,141,63,33,224,13,32,126,67,1,9,25,171],"type":"bar"},{"x":["sensitivity","generalization","corroborate","parameterized","benchmark","e ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4599,), (4599, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8216666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Latent</span> <span style='background-color:rgba(255, 0, 0, 0.5324675324675325);'>Dirichlet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Allocation</span> <span style=''>Based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Organisation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Broadcast</span> <span style=''>Media</span> <span style=''>Archives</span> <span style=''>for</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Network</span> <span style='background-color:rgba(0, 255, 0, 0.41414141414141414);'>Adaptation</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovery</span> <span style=''>of</span> <span style=''>latent</span> <span style=''>domains</span> <span style=''>in</span> <span style=''>diverse</span> <span style=''>speech</span> <span style=''>data</span> <span style=''>for</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.41414141414141414);'>adaptation</span> <span style=''>of</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>(DNNs)</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.5336322869955157);'>Automatic</span> <span style=''>Speech</span> <span style='background-color:rgba(0, 255, 0, 0.6352459016393444);'>Recognition</span> <span style=''>Our</span> <span style=''>work</span> <span style=''>focuses</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>transcription</span> <span style=''>of</span> <span style=''>multi</span> <span style=''>genre</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>broadcast</span> <span style=''>media</span> <span style=''>which</span> <span style=''>is</span> <span style=''>often</span> <span style=''>only</span> <span style=''>categorised</span> <span style=''>broadly</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>high</span> <span style=''>level</span> <span style=''>genres</span> <span style=''>such</span> <span style=''>as</span> <span style=''>sports</span> <span style=''>news</span> <span style=''>documentary</span> <span style=''>etc</span> <span style=''>However</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>acoustic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modelling</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.6153846153846154);'>categories</span> <span style=''>are</span> <span style=''>coarse</span> <span style=''>Instead</span> <span style=''>it</span> <span style=''>is</span> <span style=''>expected</span> <span style=''>that</span> <span style=''>a</span> <span style=''>mixture</span> <span style=''>of</span> <span style=''>latent</span> <span style=''>domains</span> <span style=''>can</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3879781420765027);'>represent</span> <span style=''>the</span> <span style=''>complex</span> <span style=''>and</span> <span style=''>diverse</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>behaviours</span> <span style=''>within</span> <span style=''>a</span> <span style=''>TV</span> <span style=''>show</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>therefore</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>better</span> <span style=''>and</span> <span style=''>more</span> <span style=''>robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>We</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonnegative</span> <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorization</span> <span style=''>with</span> <span style=''>Outliers</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>unified</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>systematic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performing</span> <span style=''>online</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonnegative</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>outliers</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particularly</span> <span style=''>suited</span> <span style=''>to</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>data</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>two</span> <span style=''>solvers</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projected</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>direction</span> <span style=''>method</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multipliers</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>values</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converges</span> <span style=''>almost</span> <span style=''>surely</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>appealing</span> <span style=''>to</span> <span style=''>the</span> <span style=''>quasi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>martingale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>theorem</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>learned</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionaries</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converges</span> <span style=''>to</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style=''>points</span> <span style=''>of</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>almost</span> <span style=''>surely</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>we</span> <span style=''>extend</span> <span style=''>our</span> <span style=''>basic</span> <span style=''>problem</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>to</span> <span style=''>various</span> <span style=''>settings</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3) ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.4193548387096775);'>Multiplicative</span> <span style=''>updates</span> <span style=''>For</span> <span style=''>Non</span> <span style=''>Negative</span> <span style=''>Kernel</span> <span style=''>SVM</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style='background-color:rgba(255, 0, 0, 0.4193548387096775);'>multiplicative</span> <span style=''>updates</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>hard</span> <span style=''>and</span> <span style=''>soft</span> <span style=''>margin</span> <span style=''>support</span> <span style=''>vector</span> <span style=''>machines</span> <span style=''>(SVM)</span> <span style=''>with</span> <span style=''>non</span> <span style=''>negative</span> <span style=''>kernels</span> <span style=''>They</span> <span style=''>follow</span> <span style=''>as</span> <span style=''>a</span> <span style=''>natural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>updates</span> <span style=''>for</span> <span style=''>non</span> <span style=''>negative</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.4385964912280703);'>factorization</span> <span style=''>No</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style=''>param</span> <span style=''>eter</span> <span style=''>setting</span> <span style=''>such</span> <span style=''>as</span> <span style=''>choosing</span> <span style=''>learning</span> <span style=''>rate</span> <span style=''>is</span> <span style=''>required</span> <span style=''>Ex</span> <span style=''>periments</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>rapid</span> <span style='background-color:rgba(255, 0, 0, 0.3684210526315789);'>convergence</span> <span style=''>to</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>We</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>rates</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.6153846153846154);'>asymptotic</span> <span style='background-color:rgba(255, 0, 0, 0.3684210526315789);'>convergence</span> <span style=''>of</span> <span style=''>the</span> <span style=''>up</span> <span style=''>dates</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.37931034482758624);'>establish</span> <span style=''>tight</span> <span style=''>bounds</span> <span style=''>We</span> <span style=''>test</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>several</span> <span style=''>datasets</span> <span style=''>using</span> <span style=''>various</span> <span style=''>non</span> <span style=''>negative</span> <span style=''>kernels</span> <span style=''>and</span> <span style=''>report</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>errors</span> <span style=''>to</span> <span style=''>that</span> <span style=''>of</span> <span style=''>a</span> <span style=''>standard</span> <span style=''>SVM</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Towards</span> <span style=''>Bayesian</span> <span style=''>Deep</span> <span style=''>Learning</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Framework</span> <span style=''>and</span> <span style=''>Some</span> <span style=''>Existing</span> <span style=''>Methods</span> <br/><br/><span style=''>While</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perception</span> <span style=''>tasks</span> <span style=''>such</span> <span style=''>as</span> <span style=''>visual</span> <span style=''>object</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>and</span> <span style=''>text</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>play</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>role</span> <span style=''>in</span> <span style=''>human</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intelligence</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subsequent</span> <span style=''>tasks</span> <span style=''>that</span> <span style=''>involve</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reasoning</span> <span style=''>and</span> <span style=''>planning</span> <span style=''>require</span> <span style=''>an</span> <span style=''>even</span> <span style=''>higher</span> <span style=''>level</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intelligence</span> <span style=''>The</span> <span style=''>past</span> <span style=''>few</span> <span style=''>years</span> <span style=''>have</span> <span style=''>seen</span> <span style=''>major</span> <span style=''>advances</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perception</span> <span style=''>tasks</span> <span style=''>using</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>For</span> <span style=''>higher</span> <span style=''>level</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>however</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>with</span> <span style=''>their</span> <span style=''>Bayesian</span> <span style=''>nature</span> <span style=''>are</span> <span style=''>still</span> <span style=''>more</span> <span style=''>powerful</span> <span style=''>and</span> <span style=''>flexible</span> <span style=''>To</span> <span style=''>achieve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intelligence</span> <span style=''>that</span> <span style=''>involves</span> <span style=''>both</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perception</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>naturally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>desirable</span> <span style=''>to</span> <span style=''>tightly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrate</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>Bayesian</span> <span style=''>models</span> <span style=''>within</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>which</span> <spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.12994960403167746)
# 	segmentation (0.07379409647228222)
# 	architecture (0.09107271418286537)
# 	knowledge (0.1285097192224622)
# 	different (0.25557955363570917)
# 	representation (0.13210943124550037)
# 	information (0.25413966882649386)
# 	detection (0.12275017998560116)
# 	convolutional (0.13822894168466524)
# 	recognition (0.14362850971922247)
#
# Some Statistics words are:
# 	estimation (0.1632047477744807)
# 	variables (0.1261127596439169)
# 	stochastic (0.13402571711177053)
# 	theoretical (0.1533135509396637)
# 	distribution (0.17260138476755688)
# 	algorithm (0.3961424332344214)
# 	statistical (0.15578635014836795)
# 	inference (0.19287833827893175)
# 	dimensional (0.1894164193867458)
# 	regression (0.18793273986152326)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ff659c47-230c-4449-8c83-db90965cc6e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff659c47-230c-4449-8c83-db90965cc6e5")) {                    Plotly.newPlot(                        "ff659c47-230c-4449-8c83-db90965cc6e5",                        [{"x":["sensitivity","generalization","corroborate","parameterized","benchmark","experiments","positively","prediction","incorporating","generally","correlated","therefore","generalized","applications","outperforms","robustness","performances","architecture","variations","effective","convolutional","parameters","optimization","challenging","computation","practical","complicated","principle","constraints","explanation","framework","reinforcement","integrated","extension","development","properties","environment","selective","directions","perception","different","processing","simultaneous","motivated","efficient","isolation","intrinsically","consisting","intrinsic","competitive","distribution","documents","estimation","relevance","intuition","recurrent","alternative","searching","integrate","expressive","timestamps","implementation","integration","integrating","important","leveraged","similarity","bidirectional","baselines","significant","neighboring","coherence","improvements","knowledge","penalized","selection","structural","connections","procedure","developed","permutation","including","validation","parameter","selecting","information","criterion","procedures","simulation","relationship","temperature","estimates","magnitude","conditions","excluding","associated","sentiment","investigation","meteorological","individuals","precipitation","expressed","occurring","expressions","temperatures","historical","impressive","structure","stochastic","formulation","architectures","regularization","identical","adaptation","remarkably","conclusions","implicitly","conjecture","parameterization","advancement","demonstrate","empirically","evaluation","inception","evaluating","researchers","application","systematic","generative","essential","comparing","accordance","recognition","communication","transfers","corresponding","construct","simulates","individually","principles","handwriting","comprehensive","handwritten","objective","classifier","negligible","empirical","prohibitively","environments","sufficiently","computational","proportional","especially","efficiently","incorporated","minimization","classification","modification","solutions","numerical","algorithms","pioneered","inference","phenomenon","iterative","techniques","probabilistic","criticize","analyzing","distributed","tensorflow","inferences","satisfiability","programming","translation","formalized","comparison","extensions","harnessed","preliminary","declarative","propositional","translating","experimental","particular","performance","philosophy","modelling","computing","difference","dimensions","technique","communications","association","generation","annotation","attitudes","intensities","intensity","automatic","categories","consistency","classifiers","posterior","increasing","structured","bernoulli","extraction","kernelized","combination","probabilities","coordinate","performed","regression","themselves","reformulation","localized","laplacian","optimized","approximates","comparable","interpretation","approximation","predictions","projecting","converges","dimensional","reduction","exploring","convergence","represent","representation","exponential","dimensionality","benchmarking","refinement","argumentation","following","advantage","introduce","interacting","preferred","interactions","attackers","underlying","valuation","acceptability","partition","arguments","acceptable","available","independence","demonstrated","thousands","capturing","supervise ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	criticize
# 	sparsistent
# 	attraction
# 	percolation
# 	epanechnikov
# 	embarrassingly
# 	hypernetworks
# 	hypernetwork
# 	blockmodel
# 	collinearity
# 	emphdirectly
# 	identifiability
# 	missingness
# 	sylvester
# 	cigarette
# 	stationarities
# 	geostatistical
# 	unconditional
# 	chemometrics
# 	unnecessarily
# Some words which never appear in Statistics papers:
# 	accordance
# 	satisfiability
# 	declarative
# 	propositional
# 	argumentation
# 	valuation
# 	acceptability
# 	bhattacharyya
# 	localizing
# 	comprised
# 	plasticity
# 	memristor
# 	memristive
# 	phenomenological
# 	inclusive
# 	quaternion
# 	satisfactorily
# 	associating
# 	substitutes
# 	conversational

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.08842150776738e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7841666666666667
